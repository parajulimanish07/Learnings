# %%
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing(as_frame=True).frame

# %%
pd.options.display.max_columns = 500
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
type(df.HouseAge) #series
# Out:
# pandas.core.series.Series

# %%
# df['HouseAge'].mean()
# df['HouseAge'].median()
# df['HouseAge'].mode()
# df['HouseAge'].std()
# df['HouseAge'].sum()

# %%
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20,15))
plt.tight_layout()

# %%
import yfinance as yf 

stock_df = yf.download('AAPL')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
stock_df.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df = pd.DataFrame({
    'name': ['John', 'Jane', 'Sue', 'Fred'],
    'age': [23, 29, 21, 18],
    'job': ['teacher', 'engineer', 'doctor', 'nurse'],
})

# %%
df
# Out:
#    name  age       job
# 0  John   23   teacher
# 1  Jane   29  engineer
# 2   Sue   21    doctor
# 3  Fred   18     nurse

# %%
df = df.set_index('name')

# %%
df.loc['John', 'age']
# Out:
# np.int64(23)

# %%
df.iloc[1,0]
# Out:
# np.int64(29)

# %%
df.at['Jane', 'age']
# Out:
# np.int64(29)

# %%
df.iat[1,0]
# Out:
# np.int64(29)

# %%
df.at['John', 'age'] = 62

# %%
df
# Out:
#       age       job
# name
# John   72   retired
# Jane   29  engineer
# Sue    21    doctor
# Fred   18     nurse

# %%
df.loc['John'] = [72, 'retired']

# %%
df.loc['Manish'] = [22, 'Learning']

# %%
df
# Out:
#         age       job
# name
# John     72   retired
# Jane     29  engineer
# Sue      21    doctor
# Fred     18     nurse
# Manish   22  Learning

# %%
df.iloc[0:1]
# Out:
#       age      job
# name
# John   72  retired

# %%
df.age = df.age * 2

# %%
df
# Out:
#         age       job
# name
# John    144   retired
# Jane     58  engineer
# Sue      42    doctor
# Fred     36     nurse
# Manish   44  Learning

# %%
def myfunction(x):
    if x % 3 == 0:
        return x ** 2
    else:
        return x//2

# %%
df.age.apply(myfunction)
# Out:
# name
# John      20736
# Jane         29
# Sue        1764
# Fred       1296
# Manish       22
# Name: age, dtype: int64

# %%
def myfunction2(x):
    if x.endswith('r'):
        return "WITHOUT JOB"
    else:
       return x

# %%
df.job = df.job.apply(myfunction2)

# %%
df
# Out:
#         age          job
# name
# John    144      retired
# Jane     58  WITHOUT JOB
# Sue      42  WITHOUT JOB
# Fred     36        nurse
# Manish   44     Learning

# %%
df.age.apply(lambda x: x**2 if x% 10 == 0 else x // 2)
# Out:
# name
# John      72
# Jane      29
# Sue       21
# Fred      18
# Manish    22
# Name: age, dtype: int64

# %%
df['summary']= df.apply(lambda row: f'Age: {row["age"]}, Job: {row["job"]}', axis=1)

# %%
df
# Out:
#         age          job                    summary
# name
# John    144      retired     Age: 144, Job: retired
# Jane     58  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# Sue      42  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# Fred     36        nurse        Age: 36, Job: nurse
# Manish   44     Learning     Age: 44, Job: Learning

# %%
def row_processor(row):
    return row['column']

# %%
df
# Out:
#         age          job                    summary
# name
# John    144      retired     Age: 144, Job: retired
# Jane     58  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# Sue      42  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# Fred     36        nurse        Age: 36, Job: nurse
# Manish   44     Learning     Age: 44, Job: Learning

# %%
df.drop('summary', axis=1) #axis = 1 column ani axi = 0 row
# Out:
#         age          job
# name
# John    144      retired
# Jane     58  WITHOUT JOB
# Sue      42  WITHOUT JOB
# Fred     36        nurse
# Manish   44     Learning

# %%
df.drop(['age', 'job'], axis=1)
# Out:
#                           summary
# name
# John       Age: 144, Job: retired
# Jane    Age: 58, Job: WITHOUT JOB
# Sue     Age: 42, Job: WITHOUT JOB
# Fred          Age: 36, Job: nurse
# Manish     Age: 44, Job: Learning

# %%
df
# Out:
#         age          job                    summary
# name
# John    144      retired     Age: 144, Job: retired
# Jane     58  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# Sue      42  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# Fred     36        nurse        Age: 36, Job: nurse
# Manish   44     Learning     Age: 44, Job: Learning

# %%
df.at['John', 'age'] = float('nan')

# %%
df.age.fillna(df.age.mean())
# Out:
# name
# John      45.0
# Jane      58.0
# Sue       42.0
# Fred      36.0
# Manish    44.0
# Name: age, dtype: float64

# %%
df.at['Manish', 'job'] = None

# %%
df
# Out:
#          age          job                    summary
# name
# John     NaN      retired     Age: 144, Job: retired
# Jane    58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# Sue     42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# Fred    36.0        nurse        Age: 36, Job: nurse
# Manish  44.0         None     Age: 44, Job: Learning

# %%
df[df.age.notna()]
# Out:
#          age          job                    summary
# name
# Jane    58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# Sue     42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# Fred    36.0        nurse        Age: 36, Job: nurse
# Manish  44.0         None     Age: 44, Job: Learning

# %%
for i,col in df.items():
    print(i)
# Out:
# age
# job
# summary

# %%
df
# Out:
#          age          job                    summary
# name
# John     NaN      retired     Age: 144, Job: retired
# Jane    58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# Sue     42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# Fred    36.0        nurse        Age: 36, Job: nurse
# Manish  44.0         None     Age: 44, Job: Learning

# %%
df.age > 50
# Out:
# name
# John      False
# Jane       True
# Sue       False
# Fred      False
# Manish    False
# Name: age, dtype: bool

# %%
df[-df.job.notna()]
# Out:
#          age   job                 summary
# name
# Manish  44.0  None  Age: 44, Job: Learning

# %%
df = df.reset_index()

# %%
df
# Out:
#      name   age          job                    summary
# 0    John   NaN      retired     Age: 144, Job: retired
# 1    Jane  58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# 2     Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# 3    Fred  36.0        nurse        Age: 36, Job: nurse
# 4  Manish  44.0         None     Age: 44, Job: Learning

# %%
df[(df.name.str.endswith('e')) & (df.age.notna())]
# Out:
#    name   age          job                    summary
# 1  Jane  58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# 2   Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB

# %%
df.age = df.age.fillna(30)

# %%
import datetime as dt

df['birthday'] = df['age'].apply(lambda x: dt.datetime.now() - dt.timedelta(days=365*x))

# %%
df
# Out:
#      name   age          job                    summary  \
# 0    John  30.0      retired     Age: 144, Job: retired
# 1    Jane  58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# 2     Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# 3    Fred  36.0        nurse        Age: 36, Job: nurse
# 4  Manish  44.0         None     Age: 44, Job: Learning
#
#                     birthday
# 0 1995-03-22 14:47:28.289088
# 1 1967-03-29 14:47:28.289532
# 2 1983-03-25 14:47:28.289541
# 3 1989-03-23 14:47:28.289543
# 4 1981-03-25 14:47:28.289546

# %%
df[df.birthday.dt.year > 1970]
# Out:
#      name   age          job                    summary  \
# 0    John  30.0      retired     Age: 144, Job: retired
# 2     Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# 3    Fred  36.0        nurse        Age: 36, Job: nurse
# 4  Manish  44.0         None     Age: 44, Job: Learning
#
#                     birthday
# 0 1995-03-22 14:47:28.289088
# 2 1983-03-25 14:47:28.289541
# 3 1989-03-23 14:47:28.289543
# 4 1981-03-25 14:47:28.289546

# %%
ages = [30, 44]
df[df.age.isin(ages)]
# Out:
#      name   age      job                 summary                   birthday
# 0    John  30.0  retired  Age: 144, Job: retired 1995-03-22 14:47:28.289088
# 4  Manish  44.0     None  Age: 44, Job: Learning 1981-03-25 14:47:28.289546

# %%
df.query('age > 30') #numexpression
# Out:
#      name   age          job                    summary  \
# 1    Jane  58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# 2     Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# 3    Fred  36.0        nurse        Age: 36, Job: nurse
# 4  Manish  44.0         None     Age: 44, Job: Learning
#
#                     birthday
# 1 1967-03-29 14:47:28.289532
# 2 1983-03-25 14:47:28.289541
# 3 1989-03-23 14:47:28.289543
# 4 1981-03-25 14:47:28.289546

# %%
df
# Out:
#      name   age          job                    summary  \
# 0    John  30.0      retired     Age: 144, Job: retired
# 1    Jane  58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# 2     Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# 3    Fred  36.0        nurse        Age: 36, Job: nurse
# 4  Manish  44.0         None     Age: 44, Job: Learning
#
#                     birthday
# 0 1995-03-22 14:47:28.289088
# 1 1967-03-29 14:47:28.289532
# 2 1983-03-25 14:47:28.289541
# 3 1989-03-23 14:47:28.289543
# 4 1981-03-25 14:47:28.289546

# %%
df.job = df.job.fillna('ML Engineer')

# %%
df
# Out:
#      name   age          job                    summary  \
# 0    John  30.0      retired     Age: 144, Job: retired
# 1    Jane  58.0  WITHOUT JOB  Age: 58, Job: WITHOUT JOB
# 2     Sue  42.0  WITHOUT JOB  Age: 42, Job: WITHOUT JOB
# 3    Fred  36.0        nurse        Age: 36, Job: nurse
# 4  Manish  44.0  ML Engineer     Age: 44, Job: Learning
#
#                     birthday
# 0 1995-03-22 14:47:28.289088
# 1 1967-03-29 14:47:28.289532
# 2 1983-03-25 14:47:28.289541
# 3 1989-03-23 14:47:28.289543
# 4 1981-03-25 14:47:28.289546

# %%
df = df.drop('summary', axis=1)

# %%
df
# Out:
#      name   age          job                   birthday
# 0    John  30.0      retired 1995-03-22 14:47:28.289088
# 1    Jane  58.0  WITHOUT JOB 1967-03-29 14:47:28.289532
# 2     Sue  42.0  WITHOUT JOB 1983-03-25 14:47:28.289541
# 3    Fred  36.0        nurse 1989-03-23 14:47:28.289543
# 4  Manish  44.0  ML Engineer 1981-03-25 14:47:28.289546

# %%
df.groupby('job').aggregate({
    'age': 'mean',
})
# Out:
#               age
# job
# ML Engineer  44.0
# WITHOUT JOB  50.0
# nurse        36.0
# retired      30.0

# %%
df
# Out:
#      name   age          job                   birthday
# 0    John  30.0      retired 1995-03-22 14:47:28.289088
# 1    Jane  58.0  WITHOUT JOB 1967-03-29 14:47:28.289532
# 2     Sue  42.0  WITHOUT JOB 1983-03-25 14:47:28.289541
# 3    Fred  36.0        nurse 1989-03-23 14:47:28.289543
# 4  Manish  44.0  ML Engineer 1981-03-25 14:47:28.289546

# %%
df.loc[4]=['John', 33, 'ML', None]

# %%
df
# Out:
#    name   age          job                   birthday
# 0  John  30.0      retired 1995-03-22 14:47:28.289088
# 1  Jane  58.0  WITHOUT JOB 1967-03-29 14:47:28.289532
# 2   Sue  42.0  WITHOUT JOB 1983-03-25 14:47:28.289541
# 3  Fred  36.0        nurse 1989-03-23 14:47:28.289543
# 4  John  33.0           ML                        NaT

# %%
df.groupby('job').agg({
    'age':['mean', 'min', 'max','sum']})
# Out:
#               age
#              mean   min   max    sum
# job
# ML           33.0  33.0  33.0   33.0
# WITHOUT JOB  50.0  42.0  58.0  100.0
# nurse        36.0  36.0  36.0   36.0
# retired      30.0  30.0  30.0   30.0

# %%
df
# Out:
#    name   age          job                   birthday
# 0  John  30.0      retired 1995-03-22 14:47:28.289088
# 1  Jane  58.0  WITHOUT JOB 1967-03-29 14:47:28.289532
# 2   Sue  42.0  WITHOUT JOB 1983-03-25 14:47:28.289541
# 3  Fred  36.0        nurse 1989-03-23 14:47:28.289543
# 4  John  33.0           ML                        NaT

# %%
df.sort_values('age', ascending=False)
# Out:
#    name   age          job                   birthday
# 1  Jane  58.0  WITHOUT JOB 1967-03-29 14:47:28.289532
# 2   Sue  42.0  WITHOUT JOB 1983-03-25 14:47:28.289541
# 3  Fred  36.0        nurse 1989-03-23 14:47:28.289543
# 4  John  33.0           ML                        NaT
# 0  John  30.0      retired 1995-03-22 14:47:28.289088

# %%
df1 = pd.DataFrame({
    'name': ['John', 'Jane', 'Sue'],
    'city': ['teacher', 'engineer', 'doctor'],
})

df2 = pd.DataFrame({
    'name': ['Fred', 'Sue', 'Jane'],
    'city': ['New York', 'Chicago', 'San Francisco'],
})

# %%
df2
# Out:
#    name           city
# 0  Fred       New York
# 1   Sue        Chicago
# 2  Jane  San Francisco

# %%
pd.concat([df1, df2]).reset_index().drop('index', axis=1)
# Out:
#    name           city
# 0  John        teacher
# 1  Jane       engineer
# 2   Sue         doctor
# 3  Fred       New York
# 4   Sue        Chicago
# 5  Jane  San Francisco

# %%
df1
# Out:
#    name      city
# 0  John   teacher
# 1  Jane  engineer
# 2   Sue    doctor

# %%
df2
# Out:
#    name           city
# 0  Fred       New York
# 1   Sue        Chicago
# 2  Jane  San Francisco

# %%
pd.concat([df1, df2],axis=1)
# Out:
#    name      city  name           city
# 0  John   teacher  Fred       New York
# 1  Jane  engineer   Sue        Chicago
# 2   Sue    doctor  Jane  San Francisco

# %%
df3 = pd.DataFrame({
    'name': ['man', 'par', 'mans'],
    'job': ['teacher', 'engineer', 'doctor'],
})

# %%
df3
# Out:
#    name       job
# 0   man   teacher
# 1   par  engineer
# 2  mans    doctor

# %%
pd.merge(df1, df3,on='name', how='outer') #inner is default, outer means everything, left first dataset
# Out:
#    name      city       job
# 0  Jane  engineer       NaN
# 1  John   teacher       NaN
# 2   Sue    doctor       NaN
# 3   man       NaN   teacher
# 4  mans       NaN    doctor
# 5   par       NaN  engineer
